# %%
import pandas as pd
from transformers import AutoTokenizer, AutoModelForSequenceClassification

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/contradiction/Sdata_annotated.csv")

# %%
tokenizer = AutoTokenizer.from_pretrained("ynie/roberta-large_conv_contradiction_detector_v0")
model = AutoModelForSequenceClassification.from_pretrained("ynie/roberta-large_conv_contradiction_detector_v0")
# Out:
# Some weights of the model checkpoint at ynie/roberta-large_conv_contradiction_detector_v0 were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
def process_row(row):
    row_number = row.name
    prediction = model(**tokenizer(row['hypothesis'], row['premise'], return_tensors="pt")).logits.argmax().item()
    print(f"Row {row_number} done after prediction with result: {prediction}")
    return prediction

# %%
df.shape
# Out:
# (47975, 11)

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0        paper_id  pair_id  \
# 0             0           0  ICLR_2019_1401        3
# 1             1           1    NIPS_2016_89        3
# 2             2           2    NIPS_2016_89        4
# 3             3           3    NIPS_2016_89        5
# 4             4           4    NIPS_2016_89        5
#
#                                           hypothesis  \
# 0  further the paper makes several misleading cla...
# 1  4 .i like the key idea and the speedup is very...
# 2  the idea to use sampling is nice but the analy...
# 3  to summarize i think this paper give some empi...
# 4  to summarize i think this paper give some empi...
#
#                                              premise       aspect        s1  \
# 0  the paper is rather well written but it strong...      clarity  positive
# 1  review scores reflect this reviewers impressio...  originality  negative
# 2  review scores reflect this reviewers impressio...  originality  negative
# 3  in my opinion the overall quality of the paper...    soundness  positive
# 4  the context and relevance as well as the contr...    soundness  positive
#
#          s2 line_pair label
# 0  negative    (6, 2)     n
# 1  positive   (5, 20)     n
# 2  positive   (5, 18)     n
# 3  negative   (4, 10)     n
# 4  negative   (5, 10)     n

# %%
df = df.sample(frac=1).head(100)
df['contradiction'] = df.apply(process_row, axis=1)
# Out:
# Row 33786 done after prediction with result: 0
# Row 27168 done after prediction with result: 0
# Row 9190 done after prediction with result: 0
# Row 34217 done after prediction with result: 0
# Row 46968 done after prediction with result: 0
# Row 16854 done after prediction with result: 0
# Row 18768 done after prediction with result: 1
# Row 32961 done after prediction with result: 0
# Row 24457 done after prediction with result: 0
# Row 42842 done after prediction with result: 0
# Row 16181 done after prediction with result: 0
# Row 2522 done after prediction with result: 0
# Row 21024 done after prediction with result: 0
# Row 14512 done after prediction with result: 0
# Row 31346 done after prediction with result: 0
# Row 47859 done after prediction with result: 0
# Row 45590 done after prediction with result: 0
# Row 3717 done after prediction with result: 0
# Row 40230 done after prediction with result: 0
# Row 2146 done after prediction with result: 0
# Row 37143 done after prediction with result: 0
# Row 10720 done after prediction with result: 0
# Row 24634 done after prediction with result: 0
# Row 17072 done after prediction with result: 0
# Row 43487 done after prediction with result: 0
# Row 38607 done after prediction with result: 0
# Row 23383 done after prediction with result: 0
# Row 11675 done after prediction with result: 0
# Row 2927 done after prediction with result: 0
# Row 20122 done after prediction with result: 0
# Row 39652 done after prediction with result: 0
# Row 42386 done after prediction with result: 0
# Row 46885 done after prediction with result: 0
# Row 36369 done after prediction with result: 0
# Row 46902 done after prediction with result: 0
# Row 31645 done after prediction with result: 0
# Row 23146 done after prediction with result: 0
# Row 40881 done after prediction with result: 0
# Row 42239 done after prediction with result: 0
# Row 37408 done after prediction with result: 0
# Row 15054 done after prediction with result: 0
# Row 20735 done after prediction with result: 0
# Row 19379 done after prediction with result: 0
# Row 13078 done after prediction with result: 0
# Row 7510 done after prediction with result: 0
# Row 22262 done after prediction with result: 0
# Row 47428 done after prediction with result: 0
# Row 9746 done after prediction with result: 0
# Row 370 done after prediction with result: 0
# Row 27327 done after prediction with result: 1
# Row 9327 done after prediction with result: 0
# Row 37954 done after prediction with result: 0
# Row 33181 done after prediction with result: 1
# Row 3261 done after prediction with result: 0
# Row 27674 done after prediction with result: 0
# Row 46399 done after prediction with result: 0
# Row 34684 done after prediction with result: 0
# Row 45880 done after prediction with result: 0
# Row 33257 done after prediction with result: 0
# Row 45526 done after prediction with result: 0
# Row 8683 done after prediction with result: 0
# Row 44373 done after prediction with result: 1
# Row 33489 done after prediction with result: 0
# Row 21063 done after prediction with result: 0
# Row 17761 done after prediction with result: 0
# Row 16712 done after prediction with result: 0
# Row 25995 done after prediction with result: 0
# Row 24468 done after prediction with result: 0
# Row 9834 done after prediction with result: 0
# Row 38538 done after prediction with result: 0
# Row 2289 done after prediction with result: 0
# Row 15027 done after prediction with result: 0
# Row 5550 done after prediction with result: 0
# Row 46376 done after prediction with result: 0
# Row 14212 done after prediction with result: 0
# Row 5589 done after prediction with result: 0
# Row 27943 done after prediction with result: 0
# Row 6325 done after prediction with result: 1
# Row 16034 done after prediction with result: 0
# Row 19315 done after prediction with result: 0
# Row 33218 done after prediction with result: 0
# Row 17465 done after prediction with result: 0
# Row 13592 done after prediction with result: 1
# Row 30544 done after prediction with result: 0
# Row 7130 done after prediction with result: 0
# Row 932 done after prediction with result: 0
# Row 46864 done after prediction with result: 1
# Row 23517 done after prediction with result: 0
# Row 36908 done after prediction with result: 0
# Row 39843 done after prediction with result: 0
# Row 23601 done after prediction with result: 0
# Row 32280 done after prediction with result: 0
# Row 45420 done after prediction with result: 0
# Row 35436 done after prediction with result: 0
# Row 31620 done after prediction with result: 0
# Row 4165 done after prediction with result: 0
# Row 2479 done after prediction with result: 0
# Row 43463 done after prediction with result: 0
# Row 45718 done after prediction with result: 0
# Row 291 done after prediction with result: 0

# %%
df['label'] = df['label'].apply(lambda x: 0 if x == "c" else 1)

# %%
df.head()
# Out:
#        Unnamed: 0.1  Unnamed: 0        paper_id  pair_id  \
# 33786         33786       33786   ICLR_2020_165        1
# 27168         27168       27168   NIPS_2019_772        2
# 9190           9190        9190   NIPS_2017_115        2
# 34217         34217       34217  ICLR_2019_1051        2
# 46968         46968       46968   ICLR_2020_332        3
#
#                                               hypothesis  \
# 33786   2 for the locomotion task examples i am confu...
# 27168  however i still think that the paper requires ...
# 9190   the experiments have been limited to stereo ma...
# 34217   numerical results for the link prediction tas...
# 46968   3 as for the model itself i donot find very s...
#
#                                                  premise       aspect  \
# 33786  overall the paper is well written real-world e...    soundness
# 27168  clarity the paper is clear for the most part e...      clarity
# 9190    the paper is really well written and curated ...    substance
# 34217              can you explain why this is the case     soundness
# 46968   significance - this paper proposes an interes...  originality
#
#              s1        s2 line_pair  label  contradiction
# 33786  positive  negative   (38, 7)      1              0
# 27168  positive  negative   (5, 55)      1              0
# 9190   positive  negative    (4, 6)      1              0
# 34217  negative  positive   (16, 2)      1              0
# 46968  positive  negative   (20, 7)      1              0

# %%
# prompt: confusion matrix between label and contradiction

from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(df['label'], df['contradiction'])

ax = plt.subplot()
sns.heatmap(cm, annot=True, ax=ax)  # Annotate cells with values

ax.set_xlabel('Predicted labels')
ax.set_ylabel('True labels')
ax.set_title('Confusion Matrix')
ax.xaxis.set_ticklabels(['No Contradiction', 'Contradiction'])
ax.yaxis.set_ticklabels(['No Contradiction', 'Contradiction'])

plt.show()
